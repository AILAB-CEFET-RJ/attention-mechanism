# %%
from os import listdir
import os
import xarray as xr

# %%
path = os.path.join('./20101101.nc')
ds = xr.open_mfdataset(path)

# %%
dbz = ds.equivalent_reflectivity_factor
dbz
# Out:
# <xarray.DataArray 'equivalent_reflectivity_factor' (time: 286, y: 480, x: 480)>
# dask.array<open_dataset-ee3b22f6c95421f582a46f9bb08e23f4equivalent_reflectivity_factor, shape=(286, 480, 480), dtype=float32, chunksize=(286, 480, 480), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) int32 549850 550350 550850 551350 ... 788350 788850 789350
#   * y        (y) int32 5271250 5270750 5270250 ... 5032750 5032250 5031750
#   * time     (time) datetime64[ns] 2010-11-01 ... 2010-11-01T23:55:00
# Attributes:
#     standard_name:  equivalent_reflectivity_factor
#     units:          dBZ
#     long_name:      MAX(Z) Reflectivity (dBZ)
#     valid_range:    [ 0.  52.5]
#     grid_mapping:   transverse_mercator

# %%
dbz.shape
# Out:
# (286, 480, 480)

# %%
dbz.x.values
# Out:
# array([549850, 550350, 550850, 551350, 551850, 552350, 552850, 553350,
#        553850, 554350, 554850, 555350, 555850, 556350, 556850, 557350,
#        557850, 558350, 558850, 559350, 559850, 560350, 560850, 561350,
#        561850, 562350, 562850, 563350, 563850, 564350, 564850, 565350,
#        565850, 566350, 566850, 567350, 567850, 568350, 568850, 569350,
#        569850, 570350, 570850, 571350, 571850, 572350, 572850, 573350,
#        573850, 574350, 574850, 575350, 575850, 576350, 576850, 577350,
#        577850, 578350, 578850, 579350, 579850, 580350, 580850, 581350,
#        581850, 582350, 582850, 583350, 583850, 584350, 584850, 585350,
#        585850, 586350, 586850, 587350, 587850, 588350, 588850, 589350,
#        589850, 590350, 590850, 591350, 591850, 592350, 592850, 593350,
#        593850, 594350, 594850, 595350, 595850, 596350, 596850, 597350,
#        597850, 598350, 598850, 599350, 599850, 600350, 600850, 601350,
# ...

# %%
dbz.y.values
# Out:
# array([5271250, 5270750, 5270250, 5269750, 5269250, 5268750, 5268250,
#        5267750, 5267250, 5266750, 5266250, 5265750, 5265250, 5264750,
#        5264250, 5263750, 5263250, 5262750, 5262250, 5261750, 5261250,
#        5260750, 5260250, 5259750, 5259250, 5258750, 5258250, 5257750,
#        5257250, 5256750, 5256250, 5255750, 5255250, 5254750, 5254250,
#        5253750, 5253250, 5252750, 5252250, 5251750, 5251250, 5250750,
#        5250250, 5249750, 5249250, 5248750, 5248250, 5247750, 5247250,
#        5246750, 5246250, 5245750, 5245250, 5244750, 5244250, 5243750,
#        5243250, 5242750, 5242250, 5241750, 5241250, 5240750, 5240250,
#        5239750, 5239250, 5238750, 5238250, 5237750, 5237250, 5236750,
#        5236250, 5235750, 5235250, 5234750, 5234250, 5233750, 5233250,
#        5232750, 5232250, 5231750, 5231250, 5230750, 5230250, 5229750,
#        5229250, 5228750, 5228250, 5227750, 5227250, 5226750, 5226250,
# ...

# %%
dbz.time.values
# Out:
# array(['2010-11-01T00:00:00.000000000', '2010-11-01T00:05:00.000000000',
#        '2010-11-01T00:10:00.000000000', '2010-11-01T00:15:00.000000000',
#        '2010-11-01T00:20:00.000000000', '2010-11-01T00:25:00.000000000',
#        '2010-11-01T00:30:00.000000000', '2010-11-01T00:35:00.000000000',
#        '2010-11-01T00:40:00.000000000', '2010-11-01T00:45:00.000000000',
#        '2010-11-01T00:50:00.000000000', '2010-11-01T00:55:00.000000000',
#        '2010-11-01T01:00:00.000000000', '2010-11-01T01:05:00.000000000',
#        '2010-11-01T01:10:00.000000000', '2010-11-01T01:15:00.000000000',
#        '2010-11-01T01:20:00.000000000', '2010-11-01T01:25:00.000000000',
#        '2010-11-01T01:30:00.000000000', '2010-11-01T01:35:00.000000000',
#        '2010-11-01T01:40:00.000000000', '2010-11-01T01:45:00.000000000',
#        '2010-11-01T01:50:00.000000000', '2010-11-01T01:55:00.000000000',
#        '2010-11-01T02:00:00.000000000', '2010-11-01T02:05:00.000000000',
# ...

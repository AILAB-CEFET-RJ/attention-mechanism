# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install xarray
# Out:
# Collecting xarray
#   Using cached xarray-2022.3.0-py3-none-any.whl (870 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gustavi\anaconda3\lib\site-packages (from xarray) (21.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\gustavi\anaconda3\lib\site-packages (from xarray) (1.3.4)
# Requirement already satisfied: numpy>=1.18 in c:\users\gustavi\anaconda3\lib\site-packages (from xarray) (1.20.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gustavi\anaconda3\lib\site-packages (from packaging>=20.0->xarray) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gustavi\anaconda3\lib\site-packages (from pandas>=1.1->xarray) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gustavi\anaconda3\lib\site-packages (from pandas>=1.1->xarray) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gustavi\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->xarray) (1.16.0)
# Installing collected packages: xarray
# Successfully installed xarray-2022.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install netCDF4
# Out:
# Collecting netCDF4
#   Using cached netCDF4-1.5.8-cp39-cp39-win_amd64.whl (3.0 MB)
# Requirement already satisfied: numpy>=1.9 in c:\users\gustavi\anaconda3\lib\site-packages (from netCDF4) (1.20.3)
# Collecting cftime
#   Using cached cftime-1.6.0-cp39-none-win_amd64.whl (161 kB)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.0 netCDF4-1.5.8
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge netCDF4
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Gustavi\anaconda3
#
#   added / updated specs:
#     - netcdf4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cftime-1.6.0               |   py39h5d4886f_1         161 KB  conda-forge
#     conda-4.12.0               |   py39hcbf5309_0         1.0 MB  conda-forge
#     hdf4-4.2.13                |       h712560f_2         1.3 MB
#     libnetcdf-4.6.1            |       hf59b723_4         501 KB
#     netcdf4-1.5.7              |   py39hb76ebac_0         329 KB
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#   cftime             conda-forge/win-64::cftime-1.6.0-py39h5d4886f_1
#   hdf4               pkgs/main/win-64::hdf4-4.2.13-h712560f_2
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.6.1-hf59b723_4
#   netcdf4            pkgs/main/win-64::netcdf4-1.5.7-py39hb76ebac_0
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.3-py39haa95532_0 --> conda-forge::conda-4.12.0-py39hcbf5309_0
#
#
#
# Downloading and Extracting Packages
#
# cftime-1.6.0         | 161 KB    |            |   0%
# cftime-1.6.0         | 161 KB    | 9          |  10%
# cftime-1.6.0         | 161 KB    | ########## | 100%
# cftime-1.6.0         | 161 KB    | ########## | 100%
#
# hdf4-4.2.13          | 1.3 MB    |            |   0%
# hdf4-4.2.13          | 1.3 MB    | 6          |   7%
# hdf4-4.2.13          | 1.3 MB    | ######6    |  66%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
#
# libnetcdf-4.6.1      | 501 KB    |            |   0%
# libnetcdf-4.6.1      | 501 KB    | ###1       |  32%
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
# libnetcdf-4.6.1      | 501 KB    | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# netcdf4-1.5.7        | 329 KB    |            |   0%
# netcdf4-1.5.7        | 329 KB    | 4          |   5%
# netcdf4-1.5.7        | 329 KB    | ####3      |  44%
# netcdf4-1.5.7        | 329 KB    | ########## | 100%
# netcdf4-1.5.7        | 329 KB    | ########## | 100%
#
# conda-4.12.0         | 1.0 MB    |            |   0%
# conda-4.12.0         | 1.0 MB    | 9          |   9%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
FILE = './training/20101101.nc'
ds = xr.open_mfdataset(FILE)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (x: 480, y: 480, time: 286)
# Coordinates:
#   * x                               (x) int32 549850 550350 ... 788850 789350
#   * y                               (y) int32 5271250 5270750 ... 5031750
#   * time                            (time) datetime64[ns] 2010-11-01 ... 2010...
# Data variables:
#     transverse_mercator             |S1 ...
#     equivalent_reflectivity_factor  (time, y, x) float32 dask.array<chunksize=(286, 480, 480), meta=np.ndarray>
# Attributes:
#     Conventions:         CF-1.7
#     GDAL_AREA_OR_POINT:  Area
#     title:               MAX(Z) Reflectivity day 2010-11-01
#     institution:         Meteotrentino, Fondazione Bruno Kessler
#     source:              radar observation mt.Macaion
#     site_lat_lon_elev:   46.494002, 11.208826, 1876
#     references:          original dataset https://doi.org/10.5281/zenodo.3577451
#     comments:            NetCDF generation code https://github.com/MPBA/TAASR...
#     chunks:              164 122
#     tags:                rain snow
